# %% [markdown]
# # nn.Module i nn.Linear

# %%
import torch
import torch.nn as nn

from tqdm import tqdm

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(1,1)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.linear(x)

# %%
x = torch.randn(100,1)
noise = torch.randn(100,1) * 0.1

print(x[:5])
print(noise[:5])
# Out:
# tensor([[-0.4874],
#         [-0.0232],
#         [-0.6976],
#         [-0.1212],
#         [-1.5279]])
# tensor([[ 0.0751],
#         [ 0.0063],
#         [ 0.0809],
#         [ 0.1514],
#         [-0.0964]])

# %%
y = 2 * x + 1 + noise
y[:5]
# Out:
# tensor([[ 0.1004],
#         [ 0.9598],
#         [-0.3143],
#         [ 0.9091],
#         [-2.1522]])

# %%
model = LinearRegression()
loss_fn = nn.MSELoss()

# %%
n_epochs = 1000

for epoch in tqdm(range(n_epochs)):
    model.train()
    yhat = model(x)

    loss = loss_fn(yhat,y)

    loss.backward()

    with torch.inference_mode():
        for param in model.parameters():
            if param.grad is not None:
                param -= 0.01 * param.grad

        model.zero_grad()
    if epoch % 100 == 0:
        print(f"Epoch: {epoch}, Loss: {loss.item():.4f}")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 for epoch in tqdm(range(n_epochs)):
#       4     model.train()
# ----> 5     yhat = model(x)
#       7     loss = loss_fn(yhat,y)
#       9     loss.backward()
#
# File c:\Users\posze\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\posze\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[2], line 8, in LinearRegression.forward(self, x)
#       7 def forward(self, x: torch.Tensor) -> torch.Tensor:
# ----> 8     return self.linear(x)
#
# File c:\Users\posze\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\posze\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\posze\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (100x1 and 3x1)

# %%
model.state_dict()
# Out:
# OrderedDict([('linear.weight', tensor([[2.0003]])),
#              ('linear.bias', tensor([1.0023]))])
